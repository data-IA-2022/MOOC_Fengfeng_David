# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from utils import get_config
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
engine = create_engine(get_config('mysql'))
engine
# Out:
# Engine(mysql://root:***@127.0.0.1:3306/g3_MOOC)

# %%
query = """
    Select body, polarity, subjectivity, eligibility, gender, education_level, country from Message m
    join Result r
    on m.username = r.username
    join User u
    on m.username = u.username;
    """
df = pd.read_sql(query, engine)

# %%
df['gender'] = df['gender'].replace("", np.nan)
df['country'] = df['country'].replace("", np.nan)
df['education_level'] = df['education_level'].replace("", np.nan)

# %%
df = df.dropna().drop_duplicates()

# %%
X = df.drop(columns='eligibility')
y = df['eligibility']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

# %%
X_cat = X.select_dtypes(include=[object])
X_num = X.select_dtypes(exclude=[object])

# %%
X_cat.columns
# Out:
# Index(['body', 'gender', 'education_level', 'country'], dtype='object')

# %%
col_tg = ColumnTransformer(
    transformers=[
        ('tf_num', RobustScaler(), X_num.columns),
        ('tf_cat', CountVectorizer(), 'body')
    ]
)
pipe = Pipeline(
    steps=[
        ('preparation', col_tg),
        ('model', KNeighborsClassifier())
    ]
)

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('preparation',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('tf_num',
#                                                   RobustScaler(copy=True,
#                                                                quantile_range=(25.0,
#                                                                                75.0),
#                                                                with_centering=True,
#                                                                with_scaling=True),
#                                                   Index(['polarity', 'subjectivity'], dtype='object')),
#                                                  ('tf_cat',
#                                                   CountVectorizer(analyzer='word',
#                                                                   binary=F...
#                                                                   max_features=None,
#                                                                   min_df=1,
#                                                                   ngram_range=(1,
#                                                                                1),
#                                                                   preprocessor=None,
#                                                                   stop_words=None,
#                                                                   strip_accents=None,
#                                                                   token_pattern='(?u)\\b\\w\\w+\\b',
#                                                                   tokenizer=None,
#                                                                   vocabulary=None),
#                                                   'body')],
#                                    verbose=False)),
#                 ('model',
#                  KNeighborsClassifier(algorithm='auto', leaf_size=30,
#                                       metric='minkowski', metric_params=None,
#                                       n_jobs=None, n_neighbors=5, p=2,
#                                       weights='uniform'))],
#          verbose=False)

# %%
y_max_pred = pipe.predict(X_test)
print("RFR:", round(accuracy_score(y_test, y_max_pred), 5))
# Out:
# RFR: 0.33333

# %%
from pycaret.classification import *
exp_reg101 = setup(data = df, target = 'eligibility')
# Out:
# <style type="text/css">
# #T_807e4_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_807e4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_807e4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_807e4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_807e4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_807e4_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_807e4_row0_col1" class="data row0 col1" >7411</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_807e4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_807e4_row1_col1" class="data row1 col1" >eligibility</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_807e4_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_807e4_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_807e4_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_807e4_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_807e4_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_807e4_row4_col1" class="data row4 col1" >(87, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_807e4_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_807e4_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_807e4_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_807e4_row6_col1" class="data row6 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_807e4_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_807e4_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_807e4_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_807e4_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_807e4_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_807e4_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_807e4_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_807e4_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_807e4_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_807e4_row11_col1" class="data row11 col1" >(60, 56)</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_807e4_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_807e4_row12_col1" class="data row12 col1" >(27, 56)</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_807e4_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_807e4_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_807e4_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_807e4_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_807e4_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_807e4_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_807e4_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_807e4_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_807e4_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_807e4_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_807e4_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_807e4_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_807e4_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_807e4_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_807e4_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_807e4_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_807e4_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_807e4_row21_col1" class="data row21 col1" >7fb0</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_807e4_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_807e4_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_807e4_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_807e4_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_807e4_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_807e4_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_807e4_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_807e4_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_807e4_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_807e4_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_807e4_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_807e4_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_807e4_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_807e4_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_807e4_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_807e4_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_807e4_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_807e4_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_807e4_row30_col1" class="d

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_85079 th {
#   text-align: left;
# }
# #T_85079_row0_col0, #T_85079_row0_col3, #T_85079_row0_col4, #T_85079_row0_col5, #T_85079_row1_col0, #T_85079_row1_col1, #T_85079_row1_col2, #T_85079_row1_col3, #T_85079_row1_col5, #T_85079_row1_col6, #T_85079_row1_col7, #T_85079_row2_col0, #T_85079_row2_col1, #T_85079_row2_col2, #T_85079_row2_col3, #T_85079_row2_col4, #T_85079_row2_col5, #T_85079_row2_col6, #T_85079_row2_col7, #T_85079_row3_col0, #T_85079_row3_col1, #T_85079_row3_col2, #T_85079_row3_col3, #T_85079_row3_col4, #T_85079_row3_col5, #T_85079_row3_col6, #T_85079_row3_col7, #T_85079_row4_col0, #T_85079_row4_col1, #T_85079_row4_col2, #T_85079_row4_col3, #T_85079_row4_col4, #T_85079_row4_col5, #T_85079_row4_col6, #T_85079_row4_col7, #T_85079_row5_col0, #T_85079_row5_col1, #T_85079_row5_col2, #T_85079_row5_col3, #T_85079_row5_col4, #T_85079_row5_col5, #T_85079_row5_col6, #T_85079_row5_col7, #T_85079_row6_col0, #T_85079_row6_col1, #T_85079_row6_col2, #T_85079_row6_col3, #T_85079_row6_col4, #T_85079_row6_col5, #T_85079_row6_col6, #T_85079_row6_col7, #T_85079_row7_col0, #T_85079_row7_col1, #T_85079_row7_col2, #T_85079_row7_col3, #T_85079_row7_col4, #T_85079_row7_col5, #T_85079_row7_col6, #T_85079_row7_col7, #T_85079_row8_col0, #T_85079_row8_col1, #T_85079_row8_col2, #T_85079_row8_col3, #T_85079_row8_col4, #T_85079_row8_col5, #T_85079_row8_col6, #T_85079_row8_col7, #T_85079_row9_col0, #T_85079_row9_col1, #T_85079_row9_col2, #T_85079_row9_col3, #T_85079_row9_col4, #T_85079_row9_col5, #T_85079_row9_col6, #T_85079_row9_col7, #T_85079_row10_col0, #T_85079_row10_col1, #T_85079_row10_col2, #T_85079_row10_col3, #T_85079_row10_col4, #T_85079_row10_col5, #T_85079_row10_col6, #T_85079_row10_col7, #T_85079_row11_col0, #T_85079_row11_col1, #T_85079_row11_col2, #T_85079_row11_col3, #T_85079_row11_col4, #T_85079_row11_col5, #T_85079_row11_col6, #T_85079_row11_col7, #T_85079_row12_col0, #T_85079_row12_col1, #T_85079_row12_col2, #T_85079_row12_col4, #T_85079_row12_col6, #T_85079_row12_col7 {
#   text-align: left;
# }
# #T_85079_row0_col1, #T_85079_row0_col2, #T_85079_row0_col6, #T_85079_row0_col7, #T_85079_row1_col4, #T_85079_row12_col3, #T_85079_row12_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_85079_row0_col8, #T_85079_row3_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_85079_row1_col8, #T_85079_row2_col8, #T_85079_row4_col8, #T_85079_row5_col8, #T_85079_row6_col8, #T_85079_row7_col8, #T_85079_row8_col8, #T_85079_row9_col8, #T_85079_row10_col8, #T_85079_row11_col8, #T_85079_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T